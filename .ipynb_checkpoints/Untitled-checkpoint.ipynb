# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

from numpy.lib import stride_tricks

# %%
# %matplotlib inline

# %%
masque=plt.imread('masque2.png')

# %%
masqueN=masque.mean(axis=2)

# %%
plt.imshow(masqueN,cmap=plt.cm.gray)

# %%
coords=[]
grilleCoords=np.zeros(masqueN.shape)
cpt=0
for x in range(masqueN.shape[1]):
    for y in range(masqueN.shape[0]):
        coords.append((x,y))
        grilleCoords[y,x]=cpt
        cpt+=1

# %%
pointsNoirs=[]
pts=grilleCoords[masqueN==0]
for ind in pts.reshape(pts.size):
    pointsNoirs.append(coords[int(ind)])
pointsNoirs=np.array(pointsNoirs)

# %%
XN=pointsNoirs.T[0]
YN=pointsNoirs.T[1]

# %%
masque2N=masqueN.copy()
for x,y in coords:
    if masque2N[y,x] == 1:
        dist=np.sqrt(np.min((XN-x)**2+(YN-y)**2))
        masque2N[y,x]=dist
        continue
    masque2N[y,x]=0

# %%
masque3N=masqueN.copy()
masque3N[(masque3N!=0) & (masque3N!=1)]=1/2

# %%
plt.imshow(masque3N**(1/2),cmap=plt.cm.gray)
plt.figure()
plt.imshow(masque2N**(1/2),cmap=plt.cm.jet)

# %%
import time

# %%
masque5N=masqueN.copy()
masque5N[masque5N != 1] =0
masque5N=1-masque5N
filtre=np.array(
                [[0,1,0],
                [1,0,1],
                [0,1,0]])
#filtre = filtre/np.sum(filtre)
treatment=(masque5N == 0)
megaFiltre=np.ones((masque5N.shape[0],masque5N.shape[1],3,3))
megaFiltre=(megaFiltre.T*(1-masque5N.T)).T*filtre
masque5N = masque5N * 2000
plt.imshow(masque5N,cmap=plt.cm.gray)
plt.figure()
a=[]
while np.sum(masque5N == 0) > 0:
    t=time.time()
    vois=neighbor_grid(masque5N)
    vois2=vois*megaFiltre
    added=np.max(vois2,axis=(-2,-1))-1
    masque5N[(masque5N == 0) & (added > 0)] = added[(masque5N == 0) & (added > 0)]
    a.append(time.time()-t)

plt.ylim(0,np.max(a))
plt.plot(a)
plt.figure()
plt.imshow(np.sqrt(masque5N),cmap=plt.cm.jet)

# %%
plt.figure()
plt.imshow(np.log(1+masque5N-np.min(masque5N)),cmap=plt.cm.jet)

# %%
del west
del eurasie
del est

# %%
import OceanPSC.operations as op
from OceanPSC.utils import load_data
from OceanPSC.Map import Map
import OceanPSC.clustering as clust

# %%
import importlib
clustimportlib.reload(clust)
# Out:
# <module 'OceanPSC.clustering' from 'C:\\Users\\nicol\\source\\repos\\OceanPSC\\OceanPSC\\clustering.py'>

# %%
# Open image
west = load_data('data_plus_grande.tif')
print(west.shape)
# Out:
# (5400, 5400)

# %%
from PIL import Image

# %%
rsl=Image.open('data_plus_grande.tif')
rsl=np.array(rsl)
rsl=rsl[9000:12000,]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e8afa9c9db30> in <module>()
# ----> 1 rsl=Image.open('data_plus_grande.tif')
#       2 rsl=np.array(rsl)
#       3 #rsl=rsl[9000:12000,]
#
# NameError: name 'Image' is not defined

# %%
rsl2=Image.open('eurasie.tif')
rsl2=np.array(rsl2)
rsl2=rsl2[9000:12000,]

# %%
eurasie=load_data('eurasie.tif')
print(eurasie.shape)
# Out:
# (5400, 5400)

# %%
est=load_data('est.tif')
print(est.shape)
# Out:
# (5400, 5400)

# %%
na=np.hstack((west,eurasie,est))

# %%
na=west

# %%
the_map=Map(na)

# %%
def transform(img):
    return img + 2000 * (img>=0)

# %%
dta=the_map.data[2500:2800,5300:5700]

# %%
plt.imshow(dta, cmap='terrain')

# %%
a=np.linspace(0,1)
b=np.ones(a.shape)
a,b=np.meshgrid(a,b)

# %%
plt.imshow(a, cmap='terrain')

# %%
plt.imshow(na, cmap='terrain')

# %%
a,b=na.shape
a,b=a//100,b//100
a,b
# Out:
# (54, 162)

# %%
na[1,162*100-1]
# Out:
# -4219.0

# %%
i=np.random.choice(list(range(a)))
j=np.random.choice(list(range(b)))

# %%
selection=na[100*i:100*(i+1),100*j:100*(j+1)]
plt.imshow(selection,cmap='spectral')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-fa018021445f> in <module>()
#       1 selection=na[100*i:100*(i+1),100*j:100*(j+1)]
# ----> 2 plt.imshow(selection,cmap='spectral')
#       3 plt.colorbar()
#
# C:\Users\nicol\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2728         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2729         url=url, **({"data": data} if data is not None else {}),
# -> 2730         **kwargs)
#    2731     sci(__ret)
#    2732     return __ret
#
# C:\Users\nicol\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\Users\nicol\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5519         im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    5520                               filternorm=filternorm, filterrad=filterrad,
# -> 5521                               resample=resample, **kwargs)
#    5522
#    5523         im.set_data(X)
#
# C:\Users\nicol\Anaconda3\lib\site-packages\matplotlib\image.py in __init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, **kwargs)
#     909             filterrad=filterrad,
#     910             resample=resample,
# --> 911             **kwargs
#     912         )
#     913
#
# C:\Users\nicol\Anaconda3\lib\site-packages\matplotlib\image.py in __init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, **kwargs)
#     241                  ):
#     242         martist.Artist.__init__(self)
# --> 243         cm.ScalarMappable.__init__(self, norm, cmap)
#     244         if origin is None:
#     245             origin = mpl.rcParams['image.origin']
#
# C:\Users\nicol\Anaconda3\lib\site-packages\matplotlib\cm.py in __init__(self, norm, cmap)
#     234         self.set_norm(norm)  # The Normalize instance of this ScalarMappable.
#     235         self.cmap = None  # So that the setter knows we're initializing.
# --> 236         self.set_cmap(cmap)  # The Colormap instance of this ScalarMappable.
#     237         #: The last colorbar associated with this ScalarMappable. May be None.
#     238         self.colorbar = None
#
# C:\Users\nicol\Anaconda3\lib\site-packages\matplotlib\cm.py in set_cmap(self, cmap)
#     403         """
#     404         in_init = self.cmap is None
# --> 405         cmap = get_cmap(cmap)
#     406         self.cmap = cmap
#     407         if not in_init:
#
# C:\Users\nicol\Anaconda3\lib\site-packages\matplotlib\cm.py in get_cmap(name, lut)
#     202     if isinstance(name, colors.Colormap):
#     203         return name
# --> 204     cbook._check_in_list(sorted(_cmap_registry), name=name)
#     205     if lut is None:
#     206         return _cmap_registry[name]
#
# C:\Users\nicol\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _check_in_list(_values, **kwargs)
#    2266             raise ValueError(
#    2267                 "{!r} is not a valid value for {}; supported values are {}"
# -> 2268                 .format(v, k, ', '.join(map(repr, values))))
#    2269
#    2270
#
# ValueError: 'spectral' is not a valid value for name; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'

# %%
oeuvre=np.hstack((rsl,rsl2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-e20d30fa3155> in <module>()
# ----> 1 oeuvre=np.hstack((rsl,rsl2))
#
# NameError: name 'rsl' is not defined

# %%
oeuvre=oeuvre[:,17000:25000]

# %%
rsl=rsl[15000:,]

# %%
oeuvre2=oeuvre[800:2300,4200:5800]
plt.imshow(transform(oeuvre2))

# %%
plt

# %%
np.min(oeuvre2)/(np.max(oeuvre2)-np.min(oeuvre2))
# Out:
# -0.2149560117302053

# %%
oeuvre2[oeuvre2<=10]
# Out:
# -3839

# %%
np.min(oeuvre)

# %%
plt.imshow(the_map.data)

# %%
np.max(the_map.data)
# Out:
# 8199.1875

# %%
#dta=the_map.data[1500:3000,4500:]
plt.imshow(dta,cmap='terrain')

# %%
plt.imsave('truc.png',oeuvre2,cmap='gray')

# %%
np.min(dta),np.max(dta)
# Out:
# (-455.125, 1690.25)

# %%
np.min(dta)/(np.max(dta)-np.min(dta))
# Out:
# -0.21214239934743342

# %%
plt.imshow(np.minimum(the_map.norme_grad,100))

# %%
normeGradient2=normeGradient.copy()
for i in range(20):
    normeGradient2=normeGradient2+0.1*laplacien(normeGradient2)

# %%
data,labels=the_map.get_indicators_data(indicators=clust.base_indicators,reduce=clust.reduce)

# %%
clust.base_indicators
# Out:
# [(<function numpy.mean>, None),
#  (<function numpy.mean>, <function OceanPSC.clustering.<lambda>>),
#  (<function OceanPSC.clustering.<lambda>>, None),
#  (<function OceanPSC.clustering.<lambda>>,
#   <function OceanPSC.clustering.<lambda>>)]

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans

# %% [markdown]
# red_mean,red_grad,red_minmax,red_terre_mer

# %%
filt=np.array([4,1,1,10])
truc=clust.clusters(the_map,filt,nb_cluster=4)

# %%
plt.imshow(truc,cmap='jet')

# %%
for i in range(4):
    plt.figure()
    plt.title(f"{i}: {(truc==i).mean() * 100} %")
    plt.imshow(truc==i)

# %%
plt.plot([n for n in range(3,25)],inertias)
